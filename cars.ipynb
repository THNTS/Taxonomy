# %%
import string
from east.asts import base
import glob
#import errno
import pandas as pd
import numpy as np
import re
#import imageio
#import nltk
#from nltk.tokenize import word_tokenize
#from nltk.corpus import stopwords

# %%
df1=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_1.csv")
df2=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_2.csv")
df3=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_3.csv")
df4=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_4.csv")
df5=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_5.csv")
df6=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_6.csv")
df7=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_7.csv")
df8=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_8.csv")
df9=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_9.csv")
df10=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_10.csv")
df11=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_11.csv")
df12=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_12.csv")
df13=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_13.csv")
df14=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_14.csv")
df15=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_15.csv")
df16=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_16.csv")
df17=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_17.csv")
df18=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_18.csv")
df19=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_19.csv")
df20=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_20.csv")
df21=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_21.csv")
df22=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_22.csv")
df23=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_23.csv")
df24=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_24.csv")
df25=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_25.csv")
df26=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_26.csv")
df27=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_27.csv")
df28=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_28.csv")
df29=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_29.csv")
df30=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_30.csv")
df31=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_31.csv")
df32=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_32.csv")
df33=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_33.csv")
df34=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_34.csv")
df35=pd.read_csv("/Users/daniilbabin/DS/Taxonomy/true_35.csv")

# %%
df_last=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,
               df11,df12,df13,df14,df15,df16,
               df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,
               df30,df31,df32,df33,df34,df35], axis=0)

# %%
df_last.to_csv("/Users/daniilbabin/DS/Taxonomy/final.csv")
df_last.to_excel("/final.xlsx", sheet_name='Sheet_name_1')

# %%
df_last = pd.read_csv("/Users/daniilbabin/DS/Taxonomy/final.csv")
df_last.head()
# Out:
#    Unnamed: 0  двигатель мощный      двигатель надежный  \
# 0           0          0.099967                0.102884
# 1           1          0.080353                0.265611
# 2           2          0.230226                0.256555
# 3           3          0.079340                0.105651
# 4           4          0.249276                0.374440
#
#        двигатель не ест масло      двигатель экономичный  \
# 0                    0.100805                   0.118713
# 1                    0.182922                   0.101732
# 2                    0.270609                   0.222502
# 3                    0.103166                   0.073302
# 4                    0.295418                   0.219449
#
#        двигатель не мощный       двигатель не надежный  \
# 0                  0.103831                   0.105417
# 1                  0.120177                   0.306834
# 2                  0.236293                   0.232878
# 3                  0.092236                   0.105834
# ...

# %%
# df_last = df_last.drop(["Unnamed: 0"], axis = 1)
df_last.columns = columns_1
df_last.head()
# Out:
#    1.1.1.1.   1.1.1.2.   1.1.1.3.   1.1.1.4.   1.1.1.5.   1.1.1.6.   \
# 0   0.099967   0.102884   0.100805   0.118713   0.103831   0.105417
# 1   0.080353   0.265611   0.182922   0.101732   0.120177   0.306834
# 2   0.230226   0.256555   0.270609   0.222502   0.236293   0.232878
# 3   0.079340   0.105651   0.103166   0.073302   0.092236   0.105834
# 4   0.249276   0.374440   0.295418   0.219449   0.249846   0.345711
#
#    1.1.1.7.   1.1.1.8.    1.2.1.     1.2.2.  ...    5.5.3.    5.5.4.  \
# 0   0.100163   0.119775  0.182318  0.150744  ...  0.099840  0.070667
# 1   0.161016   0.127659  0.167237  0.174894  ...  0.151473  0.055860
# 2   0.270194   0.228404  0.171425  0.109277  ...  0.109236  0.105660
# 3   0.094053   0.084238  0.121163  0.115117  ...  0.082502  0.060417
# 4   0.301224   0.223283  0.209006  0.073584  ...  0.136937  0.063695
#
#      5.5.5.    5.5.6.    5.5.7.    5.5.8.    5.5.9.   5.5.10.   5.5.11.  \
# ...

# %%
df = pd.read_excel("/Users/daniilbabin/Downloads/leafs(1).xlsx")
columns_1 = df['Номеры']
columns_1.name = ""
print(columns_1)
# Out:
# 0      1.1.1.1.
# 1      1.1.1.2.
# 2      1.1.1.3.
# 3      1.1.1.4.
# 4      1.1.1.5.
#          ...
# 111       5.5.8.
# 112       5.5.9.
# 113      5.5.10.
# 114      5.5.11.
# 115      5.5.12.
# Name: , Length: 116, dtype: object

# %%
df_last.head()
# Out:
#    1.1.1.1.   1.1.1.2.   1.1.1.3.   1.1.1.4.   1.1.1.5.   1.1.1.6.   \
# 0   0.099967   0.102884   0.100805   0.118713   0.103831   0.105417
# 1   0.080353   0.265611   0.182922   0.101732   0.120177   0.306834
# 2   0.230226   0.256555   0.270609   0.222502   0.236293   0.232878
# 3   0.079340   0.105651   0.103166   0.073302   0.092236   0.105834
# 4   0.249276   0.374440   0.295418   0.219449   0.249846   0.345711
#
#    1.1.1.7.   1.1.1.8.    1.2.1.     1.2.2.  ...    5.5.3.    5.5.4.  \
# 0   0.100163   0.119775  0.182318  0.150744  ...  0.099840  0.070667
# 1   0.161016   0.127659  0.167237  0.174894  ...  0.151473  0.055860
# 2   0.270194   0.228404  0.171425  0.109277  ...  0.109236  0.105660
# 3   0.094053   0.084238  0.121163  0.115117  ...  0.082502  0.060417
# 4   0.301224   0.223283  0.209006  0.073584  ...  0.136937  0.063695
#
#      5.5.5.    5.5.6.    5.5.7.    5.5.8.    5.5.9.   5.5.10.   5.5.11.  \
# ...

# %%
df_last.to_csv("/Users/daniilbabin/DS/Taxonomy/final_2.csv")
df_last.to_excel("/Users/daniilbabin/DS/Taxonomy/final_2.xlsx", sheet_name='Sheet_name_1')

# %%
list_of_bad = [ 299, 538, 1025, 1365, 2764, 2797, 2946,
        3036, 3124, 3211, 3342, 3640, 3684, 4246,
        4851, 4943, 5214, 5243, 5382, 5818, 6553,
        6734, 7323, 7361, 7614, 7960, 8212, 8656,
        8863, 8989, 9042, 9259, 9834, 10234, 10294,
        10613, 10760, 10874, 10941, 11103, 11570, 11925,
        12059, 12062, 12086, 12162, 12609, 12673, 12907,
        12956, 13087, 13165, 13413, 13835, 13839, 14505,
        14604, 14628, 14961, 15013, 15107, 15342, 15476,
        15845, 16257, 16277, 16781, 17250, 17293, 17668,
        17933, 18095, 18177, 18198, 18396, 18915, 19146,
        19789, 20051, 20314, 21102, 21170, 21323, 21598,
        22321, 22336, 22726, 23183, 23579, 24225, 24390,
        24608, 24686, 25347, 25408, 25460, 26203, 26481,
        26747, 26753, 26782, 26793, 26920, 27173, 27229,
        27302, 27559, 27726, 27918, 27976, 28132, 28225,
        28321, 28670, 29343, 29878, 30006, 30045,30049,
        30212, 30259, 30371, 30567, 30615, 30634, 30703,
        30895, 31136, 31231, 31244, 31405, 31435, 31502,
        31605, 32175, 32217, 32241, 32287, 32292, 32311,
        32412, 32784, 32847, 33023, 33356, 33605, 33910, 35438, 35480]

# %%
filenames = sorted(glob.glob('/Users/daniilbabin/DS/Taxonomy/35_reviews/*'))
texts = []

for name in filenames:
        l = ''
        with open(name, encoding='utf-8') as f:
            i = 0
            for line in f:
                if i >= 8:
                    l = l + "\n" + line
                i += 1
        texts.append(l)

# %%
for place in list_of_bad:
    print(place, " : ", texts[place], '\n\n\n')
# Out:
# 299  :
# Начиналось мое владение данным авто одним морозным утром, в конце января 2006 г. Стояла она на стоянке, вся замерзла,на улице -30. Открывали долго, в итоге открыли пассажирскую дверь. Бывший хозяин вставил ключ в замок и завелась она с первого раза такого я от нее не ожидал. Ладно, хватит о не интересном, начну рассказ о эксплуатации. А она такова, утром завел, вечером заглушил. Обьем двиг.2.3 литра 136 л.с, расход езжу в основном по городу составляет от 10 до 13, в зависимости от времени года и настроения. Пробег составил за все мое владение 90 000км. Из поломок, да особо ни чего не ломалось (насос гура, рейка рулевая, топливный насос), а остальное расходники. Мое впечатление очень хорошее, такую бы новую купить, но родиться надо было лет так на 20 раньше. Вот и все что хотел написать про данное авто.
#
#
#
# 538  :
# ...
